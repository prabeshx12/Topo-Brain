# %% [markdown]
# # Topo-Brain: 3T → 7T MRI Super-Resolution GAN Training
#
# **Instructions:**
# 1. Click **Runtime → Change runtime type** → Select **T4 GPU** → Save
# 2. Upload `preprocessed_data.tar` to your Google Drive root folder
# 3. Run each cell in order
# 4. Checkpoints save to your Google Drive automatically

# %%
# 1️⃣ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2️⃣ Clone Repository
# !git clone https://github.com/prabeshx12/Topo-Brain.git /content/Topo-Brain
# %cd /content/Topo-Brain

# %%
# 3️⃣ Install Dependencies
# !pip install -q nibabel scikit-image scipy matplotlib tqdm

# %%
# 4️⃣ Extract Preprocessed Data from Google Drive
# Make sure you uploaded preprocessed_data.tar to your Drive root folder!
# !tar -xvf /content/drive/MyDrive/preprocessed_data.tar -C /content/

# %%
# 5️⃣ Verify Data Structure
# !ls -la /content/preprocessed_no_n4/
# !ls /content/preprocessed_no_n4/sub-01/ses-1/anat/

# %%
# 6️⃣ Check GPU (Should show Tesla T4)
# !nvidia-smi
import torch
print(f"\nPyTorch CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")

# %%
# 7️⃣ START TRAINING 🚀
# !python scripts/train_gan.py \
    --data-root /content/preprocessed_no_n4 \
    --output-dir /content/drive/MyDrive/TopoBrain_Checkpoints \
    --epochs 100 \
    --batch_size 2 \
    --patch_size 64 \
    --num_workers 2 \
    --device cuda

# %% [markdown]
# ## Training Complete! 🎉
#
# Your checkpoints are saved to: `Google Drive/TopoBrain_Checkpoints/`
#
# - `checkpoints/` - Model weights
# - `visualizations/` - Sample outputs per epoch
# - `logs/` - Training logs
