# %% [markdown]
# # Topo-Brain: 3T → 7T MRI Super-Resolution GAN Training
#
# **Instructions:**
# 1. Click **Select Kernel** (top-right) → Choose **Colab** → Sign in with Google
# 2. Run each cell in order
# 3. Checkpoints save to your Google Drive automatically

# %%
# 1️⃣ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2️⃣ Clone Repository (uses fixed colab-ready branch)
# !git clone -b colab-ready https://github.com/prabeshx12/Topo-Brain.git /content/Topo-Brain
# %cd /content/Topo-Brain

# %%
# 3️⃣ Install Dependencies
# !pip install -q -r requirements.txt

# %%
# 4️⃣ Extract Preprocessed Data
# !tar -xvf preprocessed/preprocessed_data.tar -C /content/

# %%
# 5️⃣ Verify Data Structure (should show .nii.gz files)
# !ls /content/preprocessed_no_n4/sub-01/ses-1/anat/

# %%
# 6️⃣ Check GPU
# !nvidia-smi

# %%
# 7️⃣ START TRAINING 🚀
# !python scripts/train_gan.py \
    --data-root /content/preprocessed_no_n4 \
    --output-dir /content/drive/MyDrive/TopoBrain_Checkpoints \
    --epochs 100 \
    --batch_size 2 \
    --patch_size 64 \
    --num_workers 2 \
    --device cuda
